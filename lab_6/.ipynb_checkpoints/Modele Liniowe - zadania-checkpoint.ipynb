# %% [markdown]
# ##  Regresja liniowa
#
# Regresja liniowa to tworzenie modeli przedstawiających wielkość, której wartość chcemy przewidzieć (zmienna zależna) jako kombinację liniową predyktorów (zmiennych zależnych).
#
# Struktura modelu ma postać
#
# $$\tilde{y} = \beta_0 + \beta_1 x_1 + \beta_2 x_2 +\ldots+ \beta_n x_n$$
#
# lub w formie macierzowej
#
# $$\tilde{\mathbf{y}} = \mathbf{[1\  X ]} \beta$$
#
# gdzie wektor wartości zmiennych zależnych jest przewidywany na podstawie macierzy danych i wektora współczynników $\beta$.
#
# Współczynnik $\beta_0$ w nomentkalturze anglojęzycznej jest nazywany *intercept* ponieważ jest to punkt przecięcia się z osią $y$ gdy wszystkie predyktory są równe 0.
#
# Aby wyznaczyć parametry modelu liniowego potrzebujemy wektora danych uczących, tj. znanych nam wartości zmiennej zależnej  $\mathbf{y}$ oraz odpowiadająxcej mu macierzy predyktorów $\mathbf{X}$. Macierz predyktorów nosi nazwę *design matrix*, i bardzo użytyeczne do jej wyznaczenia (w oparciu o dane w forme dataframe) jest pakiet [patsy](https://patsy.readthedocs.io/en/latest/quickstart.html), a w szczególności funkcja ```dmatrices```.
#
#
# Model regresyjny ma mocne umocowanie statystyczne, jednak w ramach zajęć będziemy traktować go machinistycznie jak jedną z metod uczenia maszynowego. Do tworzenia takich modeli służy klasa ```LinearRegression```
#
# Do analizy regresji liniowej wykorzystywać będziemy pakiet ```scikit-learn``` oraz zawarte w nim klasy, głównie w modułach ```linear_model```, ```metrics``` oraz ```model_selection```.
#
# ### Dane uczące i dane testowe
#
# Zazwyczaj rozwiązując problem nie mamy dostępu do dodatkowych danych testowych uzupełniających nasze dane uczące. Dlatego też, popularną praktyką jest podzielenie posiadanego zbioru danych w sposób losowy na dwa zbiory: uczący i testowy. Do tego służy funkcja ```train_test_split``` z modułu ```model_selection```.

# %% [markdown]
# ### Zadanie 1
# Na podstawie danych zawartych w pliku SCORES.csv wykonaj i oceń regresję liniową, gdzie Twoją daną niezależną (predyktorem) będą godziny poświęcone na przygotowanie, a wynikową uzyskane punkty. Wykonanie zadania powinno składać się z następujących kroków:
# 1. Zaimportowanie niezbędnych bibliotek w szczególności tych tworzących modele liniowe z "scikit-learn", a także biblioteki do operacji na danych oraz tworzenia wykresów.
# 2. Odczytaj dane z pliku SCORES.csv. Pomocne w interpretacji danych są metody: head(), describe(), shape.
# 3. Wykonaj wstępny wykres uzyskanych danych (typu "scatter")
# 4. Dokonaj podziału danych na zbiory danych niezależnych (wejściowe, X) oraz zaleznych (wyjściowe, y) dla swojego modelu, a następnie podziel zbiór na dane testowe i treningowe (30%)
# 5. Utwróz model regresji liniowej za pomocą sklearn.
# 6. Wypisz i przeanalizuj wyliczone wskaźniki dla modelu: coef_ oraz intercept_. Czym one są i do czego służą?
# 7. Wykorzystając stworozny model dokonaj predykcji dla części testowej X. Porównaj wynik (y_pred) z posiadanymi danymi (y_test).
# 8. Wykonaj wykres konfrontujący dane testowe (X_test, y_test; typu "scatter") oraz predykcje (X_test, y_pred; linia prosta)
# 9. Dokonaj walidacji uzyskanych predykcji wykorzystując metryki: średni błąd bezwzględny (Mean Absolute Error), błąd średniokwadratowy (Mean Squared Error) oraz pierwiastek błędu średniokwadratowego (Root Mean Squared Error).
#
# Następnie utworzony skrypt wykorzystaj na danych zawartych w SBP.csv, gdzie predyktorem będzie wiek, a wynikiem ciśnienie (SBP). Czy uzyskane wyniki z modelu są równie zadowalające?

# %%
#1
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, classification_report
import numpy as np

# %%
#2
heart = pd.read_csv("HEART.csv")
petrol = pd.read_csv("PETROL.csv")
sbp = pd.read_csv("SBP.csv")
scores = pd.read_csv("SCORES.csv")

print(f"Wymiary: {scores.shape}")
scores.head()
# Out:
# Wymiary: (25, 2)
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
scores.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
#Wstępny wykes danych
scores.plot.scatter(x='Hours', y='Scores', grid=True, title='Wstępny wykres danych');

# %%
# X dane wejściowe
# Y dane wyjściowe

    
#Podział na zbiory treningowe i testowe
#X_train, y_train - zbiory treningowe
#X_test, y_test - zbiory testowe
X_train, X_test, y_train, y_test = train_test_split(scores.Hours, scores.Scores, train_size=0.3, random_state= 0, shuffle=True)
    
X_train = np.array(X_train).reshape(-1, 1)
X_test = np.array(X_test).reshape(-1, 1)
y_train = np.array(y_train).reshape(-1, 1)
y_test = np.array(y_test).reshape(-1, 1)

#Utworzenie modelu regresji
model_regresji = LinearRegression().fit(X_train, y_train)
    
#Wskaźniki coef_ i intercept_
print(f'Wskaźnik coef_ jest równy : {model_regresji.coef_}')
print(f'Wskaźnik intercept_ jest równy : {model_regresji.intercept_}')
    
#Predykcja części testowej X
y_pred = model_regresji.predict(X_test)
    
#Porównanie predykcji z posiadanymi danymi
fig, ax = plt.subplots(figsize=(10,7))
    
#Wykres konfrontujący dane testowe (X_test, y_test; typu "scatter") 
ax.scatter(X_test, y_test, label='y_test');
    
# Wykres predykcje (X_test, y_pred; linia prosta)
ax.plot(X_test, y_pred, 'r', label='y_pred');
ax.set_xlim(0,10)
ax.set_ylim(0,100)
ax.set_xlabel('Hours')
ax.set_ylabel('Scores')
ax.set_title('Porównanie wartości przewidzianych i rzeczywistych')
ax.legend()
ax.grid()

plt.show()

# Walidacja predykcji
MAE = mean_absolute_error(y_test, y_pred) #średni błąd bezwzględny
MSE = mean_squared_error(y_test, y_pred)  #błąd średniokwadratowy
RMSE = np.sqrt(MSE) #pierwiastek błędu średniokwadratowego
print(f'Średni błąd bezwgzlędny wynosi = {MAE}')
print(f'Błąd średniokwadratowy wynosi = {MSE}')
print(f'Pierwiastek błędu średniokwadratowego = {RMSE}')
# Out:
# Wskaźnik coef_ jest równy : [[9.8479817]]
# Wskaźnik intercept_ jest równy : [1.09792635]
# Średni błąd bezwgzlędny wynosi = 5.001787485958392
# Błąd średniokwadratowy wynosi = 28.474750355381573
# Pierwiastek błędu średniokwadratowego = 5.336173756108544

# %% [markdown]
# **Wskaźniki**
# **Wskaźnik coef_** to współczynnik kombinacji liniowej predyktorów. Mając dany tylko jeden predyktor otrzymujemy 1 współczynnik dodatkowo jest on współczynnikiem kierunkowym prostej regresji liniowej.
# **Wskaźnik intercept** to współczynnik zerowy, oznacza przecięcie z wykresu regresji liniowej z osią y.
#
# W naszym przypadku Scores = coef_*Hours + intercept
#
# W tym przypadku nasza regresja liniowa jest dobra, pokazuje nam to nasz wykres oraz wartości poszczególnych błędów. Dane nie są ("rozrzucone").

# %%
# Następne dane SBP.csv, gdzie predyktorem będzie wiek, a wynikiem ciśnienie (SBP)
print(f"Wymiary: {sbp.shape}")
sbp.head()
# Out:
# Wymiary: (19, 2)
#    Age  SBP
# 0   60  117
# 1   61  120
# 2   74  145
# 3   57  129
# 4   63  132

# %%
sbp.describe()
# Out:
#              Age         SBP
# count  19.000000   19.000000
# mean   64.947368  129.421053
# std     7.214751   13.454928
# min    54.000000  111.000000
# 25%    60.500000  119.000000
# 50%    63.000000  129.000000
# 75%    68.500000  137.000000
# max    79.000000  163.000000

# %%
#Wstępny wykes danych
sbp.plot.scatter(x='Age', y='SBP', grid=True, title='Wstępny wykres danych');

# %%
# X dane wejściowe
# Y dane wyjściowe
    
#Podział na zbiory treningowe i testowe
#X_train, y_train - zbiory treningowe
#X_test, y_test - zbiory testowe
X_train, X_test, y_train, y_test = train_test_split(sbp.Age, sbp.SBP, train_size=0.3, random_state= 0, shuffle=True)
    
X_train = np.array(X_train).reshape(-1, 1)
X_test = np.array(X_test).reshape(-1, 1)
y_train = np.array(y_train).reshape(-1, 1)
y_test = np.array(y_test).reshape(-1, 1)

#Utworzenie modelu regresji
model_regresji = LinearRegression().fit(X_train, y_train)
    
#Wskaźniki coef_ i intercept_
print(f'Wskaźnik coef_ jest równy : {model_regresji.coef_}')
print(f'Wskaźnik intercept_ jest równy : {model_regresji.intercept_}')
    
#Predykcja części testowej X
y_pred = model_regresji.predict(X_test)
    
#Porównanie predykcji z posiadanymi danymi
fig, ax = plt.subplots(figsize=(10,7))
    
#Wykres konfrontujący dane testowe (X_test, y_test; typu "scatter") 
ax.scatter(X_test, y_test, label='y_test');
    
# Wykres predykcje (X_test, y_pred; linia prosta)
ax.plot(X_test, y_pred, 'r', label='y_pred');
ax.set_xlim(52,80)
ax.set_ylim(110,160)
ax.set_xlabel('Age')
ax.set_ylabel('SBP')
ax.set_title('Porównanie wartości przewidzianych i rzeczywistych')
ax.legend()
ax.grid()

plt.show()

# Walidacja predykcji
MAE = mean_absolute_error(y_test, y_pred) #średni błąd bezwzględny
MSE = mean_squared_error(y_test, y_pred)  #błąd średniokwadratowy
RMSE = np.sqrt(MSE) #pierwiastek błędu średniokwadratowego
print(f'Średni błąd bezwgzlędny wynosi = {MAE}')
print(f'Błąd średniokwadratowy wynosi = {MSE}')
print(f'Pierwiastek błędu średniokwadratowego = {RMSE}')
# Out:
# Wskaźnik coef_ jest równy : [[0.79344729]]
# Wskaźnik intercept_ jest równy : [72.71509972]
# Średni błąd bezwgzlędny wynosi = 9.234839234839237
# Błąd średniokwadratowy wynosi = 154.7828131033259
# Pierwiastek błędu średniokwadratowego = 12.441174104694698

# %% [markdown]
# **Komentarz**
# W tym przypadku regresja liniowa zdecydowanie jest gorsza. Dane są rozproszone i nieregularne. Dodatkowo nasze błędy nie są satysfakcjonujące.

# %% [markdown]
# ### Zadanie 2
# Na podstawie danych zawartych w pliku PETROL.csv wykonaj i oceń regresję liniową. Jako daną zależną wykorzystaj zużycie paliwa, a pozostałe - jako predyktory. Wykonanie zadania powinno składać się z kroków podobnych do tych z zadania poprzedniego.
#
# Czy uzyskane wyniki predykcji modelu są dobre? Co mogło mieć pozytywny/negatywny wpływ na taki wynik?

# %%
petrol = pd.read_csv("PETROL.csv")
# PETROL.csv
print(f"Wymiary: {petrol.shape}")
petrol.head()
# Out:
# Wymiary: (48, 5)
#    Podatek_paliwowy  Sredni_przychod  Utwardzone_autostrady  \
# 0               9.0             3571                   1976
# 1               9.0             4092                   1250
# 2               9.0             3865                   1586
# 3               7.5             4870                   2351
# 4               8.0             4399                    431
#
#    Procent_ludnosci_z_prawem_jazdy  Zuzycie_paliwa
# 0                            0.525             541
# 1                            0.572             524
# 2                            0.580             561
# 3                            0.529             414
# 4                            0.544             410

# %%
petrol.describe()
# Out:
#        Podatek_paliwowy  Sredni_przychod  Utwardzone_autostrady  \
# count         48.000000        48.000000              48.000000
# mean           7.668333      4241.833333            5565.416667
# std            0.950770       573.623768            3491.507166
# min            5.000000      3063.000000             431.000000
# 25%            7.000000      3739.000000            3110.250000
# 50%            7.500000      4298.000000            4735.500000
# 75%            8.125000      4578.750000            7156.000000
# max           10.000000      5342.000000           17782.000000
#
#        Procent_ludnosci_z_prawem_jazdy  Zuzycie_paliwa
# count                        48.000000       48.000000
# mean                          0.570333      576.770833
# std                           0.055470      111.885816
# min                           0.451000      344.000000
# 25%                           0.529750      509.500000
# 50%                           0.564500      568.500000
# ...

# %%
#Daną zależną przyjmuje jako zużycie paliwa, a pozostałe - jako predyktory.
X = petrol[['Podatek_paliwowy', 'Sredni_przychod', 'Utwardzone_autostrady', 'Procent_ludnosci_z_prawem_jazdy']]
y = petrol.Zuzycie_paliwa

#Wstępny wykres danych
f, ax1 = plt.subplots(2,2,figsize=(16,16))
ax1[0,0].scatter(petrol.Podatek_paliwowy, y)
ax1[0,0].set_xlabel("Podatek paliwowy")
ax1[0,0].set_ylabel("Zużycie paliwa")
ax1[0,0].grid(True)

ax1[0,1].scatter(petrol.Sredni_przychod, y)
ax1[0,1].set_xlabel("Średni przychód")
ax1[0,1].set_ylabel("Zużycie paliwa")
ax1[0,1].grid(True)

ax1[1,0].scatter(petrol.Utwardzone_autostrady, y)
ax1[1,0].set_xlabel("Utwardzone autostrady")
ax1[1,0].set_ylabel("Zużycie paliwa")
ax1[1,0].grid(True)

ax1[1,1].scatter(petrol.Procent_ludnosci_z_prawem_jazdy, y)
ax1[1,1].set_xlabel("Procent_ludnosci_z_prawem_jazdy")
ax1[1,1].set_ylabel("Zużycie paliwa")
ax1[1,1].grid(True)


plt.show()

# %%
#Podział na zbiory treningowe i testowe
#X_train, y_train - zbiory treningowe
#X_test, y_test - zbiory testowe

X = petrol[['Podatek_paliwowy', 'Sredni_przychod', 'Utwardzone_autostrady', 'Procent_ludnosci_z_prawem_jazdy']]
y = petrol.Zuzycie_paliwa

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.3, random_state= 10, shuffle=True)
    
X_train = np.array(X_train)
X_test = np.array(X_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

#Utworzenie modelu regresji
model_regresji = LinearRegression().fit(X_train, y_train)
    
#Wskaźniki coef_ i intercept_
print(f'Wskaźnik coef_ jest równy = {model_regresji.coef_}')
print(f'Wskaźnik intercept_ jest równy = {model_regresji.intercept_}')
    
#Predykcja części testowej X
y_pred = model_regresji.predict(X_test)
    

# Walidacja predykcji
MAE = mean_absolute_error(y_test, y_pred) #średni błąd bezwzględny
MSE = mean_squared_error(y_test, y_pred)  #błąd średniokwadratowy
RMSE = np.sqrt(MSE) #pierwiastek błędu średniokwadratowego
print(f'Średni błąd bezwgzlędny wynosi = {MAE}')
print(f'Błąd średniokwadratowy wynosi = {MSE}')
print(f'Pierwiastek błędu średniokwadratowego = {RMSE}')
# Out:
# Wskaźnik coef_ jest równy = [-4.66390478e+01 -7.07004822e-02 -7.19212981e-03  9.99411116e+02]
# Wskaźnik intercept_ jest równy = 718.5834603144325
# Średni błąd bezwgzlędny wynosi = 60.417457040280276
# Błąd średniokwadratowy wynosi = 5812.027531748099
# Pierwiastek błędu średniokwadratowego = 76.23665477805345

# %%
fig, ax = plt.subplots(2, 2, figsize=(25, 25))

#zwraca wersję tablicy
ax = ax.flatten()

#i - zmienna odpowiadająca zużyciu paliwa
#p - zmienna odpowiadająca za Podatek_paliwowy,Sredni_przychod,Utwardzone_autostrady,Procent_ludnosci_z_prawem_jazdy
for i, p in enumerate(X):
    #Dana zależna
    ax[i].scatter(X_test[:, i], y_test, label="Dane zależne")
    
    punkty = sorted([(X_test[j, i], y_pred[j]) for j in range(len(y_pred)-1)],reverse=True)
    
    #Ograniczenia
    x0, y0 = punkty[0]
    xn, yn = punkty[-1]
    x_1 = (x0, xn)
    y_1 = (y0, yn)
    
    #Predykcja
    ax[i].plot(x_1, y_1, c="g", label="Predykcje")
    ax[i].set_xlabel(p)
    ax[i].set_ylabel("Zużycie paliwa")
    ax[i].legend()
    ax[i].grid()

plt.show()

# %% [markdown]
# **Komentarz**
# W tym przypadku predykcja jest bardzo słaba. Najlepsze dopasowanie naszej regresji występuje dla ostatniego przypadku czyli dla "Procentu_ludnosci_z_prawem_jazdy". Może to wynikać z tego, że obie zmienne są w stosunku do siebie najbardziej skorelowane.

# %% [markdown]
# ### Regresja logistyczna
#
# Naturalnym rozwojem modeli linowych, są uogólnione modele liniowe (*generalized linear models*).
#
# Ich przewodnią ideą jest to, że zamiast reprezentować zmienną zależną jako kombinację liniową niezależnych, staramy się stworzyć model liniowy pewnej funkcji zmiennej zależnej.
#
# $$ f(y) =  \beta_0 + \beta_1 x_1 + \beta_2 x_2 +\ldots+ \beta_n x_n$$
#
# wymaga się, aby funkcja ta była odwracalna, dzięki czemu
#
# $$ y = f^{-1} ( \beta_0 + \beta_1 x_1 + \beta_2 x_2 +\ldots+ \beta_n x_n)$$
#
# Takie przekształcenie stosujemy wtedy, gdy zbiór wartości zmiennej zależnej nie jest całym zbiorem liczb rzeczywistych tylko jest w jakiś sposób ograniczony. Na przykład do przedziału $[0,1]$, do wartości dodatnich lub wartości całkowitych. W tens posób można wybrać funkcję $f$, której dziedziną jest zbiór wartości $y$ zaś obrazem jest zbiór liczb rzeczywistych.
#
# Jedną z takich funkcji jest tzw. funkcja logistyczna, która odpowiada zbiorowi $[0,1]$ przez co często jest wykorzystywana do analizy prawdopodobieństwa przynależności do danej klasy, lub też inaczej jako klasyfikator.
#
# W takiej sytuacji zmienne zależne powinny przyjmować wyłącznie wartości $0$ i $1$ co odpowiada temu czy dany punkt należy do interesującej klasy. Model logistyczny poznwala na określenie estymaty prawdopodobieństwa, czy punkt należy czy nie do danej klasy.
#
# Do tworzenia modeli logistycznyc służy klasa: ```LogisticRegression```

# %% [markdown]
# ### Zadanie 3
#
# Na podstawie danych zawartych w pliku HEART.csv wykonaj i oceń regresję logistyczną, gdzie Twoją daną zależną jest kolumna "num". Wykonanie zadania powinno składać się z następujących kroków:
#
# 1. Zaimportowanie niezbędnych bibliotek w szczególności tych tworzących modele liniowe z "scikit-learn", a także biblioteki do operacji na danych oraz tworzenia wykresów.
# 2. Odczytanie danych z pliku HEART.csv. Pomocne w interpretacji danych są metody: head(), describe(), shape.
# 3. Przetworzenie danych, tj: oznaczenie braku danych ("?") na NaN, usunięcię kolumn zawierających zbyt dużo brakujących danych (3 kolumny), usunięcie wierszy z brakującymi wartościami.
# 4. Zakoduj niezależne zmienne kategorialne np: jako wartości "dummy", za pomoca metody get_dummies(). Zmienne kategorialne to takie, które reprezentuja przynależność do kategorii. W przypadku naszych odfiltrowanych danych będą to kolumny: cp, restecg, fbs, sex, exang. Jako, że trzy ostatnie już zapisane są w formie 0 i 1 tylko cp i restecg wymagają tej operacji.
# 5. Dokonaj podziału danych na zbiory danych niezależnych (wejściowe, X) oraz zależnych (wyjściowe, y) dla swojego modelu, a następnie podziel zbiór na dane testowe i treningowe (20%).
# 6. Utwróz model regresji logistycznej.
# 7. Oceń wynik za pomocą dostępnych metryk (np: metody związane z modelem czy classification_report() z sklearn)
#
# Możesz również spróbować ustandaryzować dane (np: poprzez skalowanie) po podziale na zbiory treningowy i testowy.

# %%
heart = pd.read_csv("HEART.csv")

# %%
# Heart.csv
print(f"Wymiary: {heart.shape}")
heart.describe()
# Out:
# Wymiary: (294, 14)
#               age         sex          cp     oldpeak  num
# count  294.000000  294.000000  294.000000  294.000000  294.000000
# mean    47.826531    0.724490    2.982993    0.586054    0.360544
# std      7.811812    0.447533    0.965117    0.908648    0.480977
# min     28.000000    0.000000    1.000000    0.000000    0.000000
# 25%     42.000000    0.000000    2.000000    0.000000    0.000000
# 50%     49.000000    1.000000    3.000000    0.000000    0.000000
# 75%     54.000000    1.000000    4.000000    1.000000    1.000000
# max     66.000000    1.000000    4.000000    5.000000    1.000000

# %%
heart.head()
# Out:
#    age  sex  cp trestbps chol fbs restecg thalach exang  oldpeak slope ca  \
# 0   28    1   2      130  132   0       2     185     0      0.0     ?  ?
# 1   29    1   2      120  243   0       0     160     0      0.0     ?  ?
# 2   29    1   2      140    ?   0       0     170     0      0.0     ?  ?
# 3   30    0   1      170  237   0       1     170     0      0.0     ?  ?
# 4   31    0   2      100  219   0       1     150     0      0.0     ?  ?
#
#   thal  num
# 0    ?           0
# 1    ?           0
# 2    ?           0
# 3    6           0
# 4    ?           0

# %%
#3 Przetworzenie danych
heart = heart.replace('?', np.nan)
del heart['slope']
del heart['ca']
del heart['thal']
heart = heart.dropna()
heart
# Out:
#      age  sex  cp trestbps chol fbs restecg thalach exang  oldpeak  num
# 0     28    1   2      130  132   0       2     185     0      0.0           0
# 1     29    1   2      120  243   0       0     160     0      0.0           0
# 3     30    0   1      170  237   0       1     170     0      0.0           0
# 4     31    0   2      100  219   0       1     150     0      0.0           0
# 5     32    0   2      105  198   0       0     165     0      0.0           0
# ..   ...  ...  ..      ...  ...  ..     ...     ...   ...      ...         ...
# 289   52    1   4      160  331   0       0      94     1      2.5           1
# 290   54    0   3      130  294   0       1     100     1      0.0           1
# 291   56    1   4      155  342   1       0     150     1      3.0           1
# 292   58    0   2      180  393   0       0     110     1      1.0           1
# 293   65    1   4      130  275   0       1     115     1      1.0           1
#
# [261 rows x 11 columns]

# %%
#4
dumny = pd.get_dummies(heart, columns=['cp', 'restecg'], drop_first=True)
dumny
# Out:
#      age  sex trestbps chol fbs thalach exang  oldpeak  num         cp_1  \
# 0     28    1      130  132   0     185     0      0.0           0     0
# 1     29    1      120  243   0     160     0      0.0           0     0
# 3     30    0      170  237   0     170     0      0.0           0     1
# 4     31    0      100  219   0     150     0      0.0           0     0
# 5     32    0      105  198   0     165     0      0.0           0     0
# ..   ...  ...      ...  ...  ..     ...   ...      ...         ...   ...
# 289   52    1      160  331   0      94     1      2.5           1     0
# 290   54    0      130  294   0     100     1      0.0           1     0
# 291   56    1      155  342   1     150     1      3.0           1     0
# 292   58    0      180  393   0     110     1      1.0           1     0
# 293   65    1      130  275   0     115     1      1.0           1     0
#
#      cp_2  cp_3  cp_4  restecg_0  restecg_1  restecg_2
# ...

# %%
#5
#Podział na zbiory treningowe i testowe
#X_train, y_train - zbiory treningowe
#X_test, y_test - zbiory testowe

#Podział danych na zbiory danych niezależnych (wejściowe, X) oraz zależnych (wyjściowe, y)
X = dumny[list(dumny.columns[:8]) + list(dumny.columns[9:])]
y = dumny[dumny.columns[8]]

#Podział zbioru na dane testowe i treningowe (20%).
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.2, random_state= 0, shuffle=True)
    
X_train = np.array(X_train)
X_test = np.array(X_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

#6
#Utworzenie modelu regresji
model_regresji = LogisticRegression(max_iter=10000).fit(X_train, y_train)
    
#Wskaźniki coef_ i intercept_
print(f'Wskaźnik coef_ jest równy = {model_regresji.coef_}','\n')
print(f'Wskaźnik intercept_ jest równy = {model_regresji.intercept_}','\n')
    
#Predykcja części testowej X
y_pred = model_regresji.predict(X_test)
    

# Walidacja predykcji
MAE = mean_absolute_error(y_test, y_pred) #średni błąd bezwzględny
MSE = mean_squared_error(y_test, y_pred)  #błąd średniokwadratowy
RMSE = np.sqrt(MSE) #pierwiastek błędu średniokwadratowego
print(f'Średni błąd bezwgzlędny wynosi = {MAE}')
print(f'Błąd średniokwadratowy wynosi = {MSE}')
print(f'Pierwiastek błędu średniokwadratowego = {RMSE}','\n')

#Metryka
target_names = ['class 1', 'class 2']
print(classification_report(y_test, y_pred,target_names=target_names))
# Out:
# Wskaźnik coef_ jest równy = [[ 0.01465144  1.13792821  0.00565799  0.00161998 -0.31672155 -0.01116972
#    1.00233828  0.54688314  0.06843758 -0.66340063  0.25072154  0.33356319
#    0.05276674 -0.06344507  0.        ]]
#
# Wskaźnik intercept_ jest równy = [-2.08735125]
#
# Średni błąd bezwgzlędny wynosi = 0.17703349282296652
# Błąd średniokwadratowy wynosi = 0.17703349282296652
# Pierwiastek błędu średniokwadratowego = 0.4207534822469881
#
#               precision    recall  f1-score   support
#
#      class 1       0.86      0.87      0.87       137
#      class 2       0.75      0.74      0.74        72
#
#     accuracy                           0.82       209
#    macro avg       0.80      0.80      0.80       209
# weighted avg       0.82      0.82      0.82       209

# %% [markdown]
# **Komentarz**
# Analizując powyższą metryke można stwierdzić, że regresja logistyczna działa zadowalająco. Ważne jest to, że nasze błędy nie są zbyt duże.
